# %%
# Use this cell to set up import statements for all of the packages that you
#   plan to use.

# Remember to include a 'magic word' so that your visualizations are plotted
#   inline with the notebook. See this page for more:
#   http://ipython.readthedocs.io/en/stable/interactive/magics.html
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %% [markdown]
# Investigating the shape of Data.

# %%
# Load your data and print out a few lines. Perform operations to inspect data
#   types and look for instances of missing or possibly errant data.
df = pd.read_csv('tmdb_movies_data.csv')
df.head
# Out:
# <bound method NDFrame.head of           id    imdb_id  popularity     budget     revenue  \
# 0     135397  tt0369610   32.985763  150000000  1513528810
# 1      76341  tt1392190   28.419936  150000000   378436354
# 2     262500  tt2908446   13.112507  110000000   295238201
# 3     140607  tt2488496   11.173104  200000000  2068178225
# 4     168259  tt2820852    9.335014  190000000  1506249360
# ...      ...        ...         ...        ...         ...
# 6642    9973  tt0470982    0.826291    9000000           0
# 6643     503  tt0409182    0.826011  160000000   181674817
# 6644    9310  tt0465142    0.793804   17000000     7314027
# 6645   14620  tt0457297    0.793059          0           0
# 6646   14611  tt0803093    0.791780          0     7900000
#
#                     original_title  \
# 0                   Jurassic World
# 1               Mad Max: Fury Road
# 2                        Insurgent
# 3     Star Wars: The Force Awakens
# 4                        Furious 7
# ...                            ...
# 6642                   Air Buddies
# 6643                      Poseidon
# 6644               American Dreamz
# 6645        The Butterfly Effect 2
# 6646           Ultimate Avengers 2
#
#                                                    cast  \
# 0     Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1     Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2     Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3     Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4     Vin Diesel|Paul Walker|Jason Statham|Michelle ...
# ...                                                 ...
# 6642  Abigail Breslin|Trevor Wright|Slade Pearce|Mic...
# 6643  Kurt Russell|Richard Dreyfuss|Josh Lucas|Jacin...
# 6644  Hugh Grant|Dennis Quaid|Mandy Moore|Willem Daf...
# 6645  Eric Lively|Erica Durance|Dustin Milligan|Gina...
# 6646                                           Justin G
#
#                                                homepage           director  \
# 0                         http://www.jurassicworld.com/    Colin Trevorrow
# 1                           http://www.madmaxmovie.com/      George Miller
# 2        http://www.thedivergentseries.movie/#insurgent   Robert Schwentke
# 3     http://www.starwars.com/films/star-wars-episod...        J.J. Abrams
# 4                              http://www.furious7.com/          James Wan
# ...                                                 ...                ...
# 6642                                                NaN       Robert Vince
# 6643               http://www2.warnerbros.com/poseidon/  Wolfgang Petersen
# 6644                                                NaN         Paul Weitz
# 6645  http://www.newline.com/properties/butterflyeff...   John R. Leonetti
# 6646                                                NaN                NaN
#
#                                                 tagline  ...  \
# 0                                     The park is open.  ...
# 1                                    What a Lovely Day.  ...
# 2                            One Choice Can Destroy You  ...
# 3                         Every generation has a story.  ...
# 4                                   Vengeance Hits Home  ...
# ...                                                 ...  ...
# 6642                                                NaN  ...
# 6643                                             Mayday  ...
# 6644  Imagine a country where more people vote for a...  ...
# 6645  Can you change your past without destroying yo...  ...
# 6646                                                NaN  ...
#
#                                                overview runtime  \
# 0     Twenty-two years after the events of Jurassic ...   124.0
# 1     An apocalyptic story set in the furthest reach...   120.0
# 2     Beatrice Prior must confront her inner demons ...   119.0
# 3     Thirty years after defeating the Galactic Empi...   136.0
# 4     Deckard Shaw seeks revenge against Dominic Tor...   137.0
# ...                                                 ...     ...
# 6642  Hereâ€™s the delightful tale of teamwork and a...    80.0
# 6643  A packed cruise ship traveling the Atlantic is...    99.0
# 6644  The new season of "American Dreamz," the wildl...   107.0
# 6645  After his girlfriend, Julie and two best frien...    95.0
# 6646                                                NaN     NaN
#
#                                          genres  \
# 0     Action|Adventure|Science Fiction|Thriller
# 1     Action|Adventure|Science Fiction|Thriller
# 2            Adventure|Science Fiction|Thriller
# 3      Action|Adventure|Science Fiction|Fantasy
# 4                         Action|Crime|Thriller
# ...                                         ...
# 6642              Comedy|Family|Science Fiction
# 6643            Adventure|Action|Drama|Thriller
# 6644                        Comedy|Drama|Family
# 6645             Drama|Science Fiction|Thriller
# 6646                                        NaN
#
#                                    production_companies release_date  \
# 0     Universal Studios|Amblin Entertainment|Legenda...     6/9/2015
# 1     Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015
# 2     Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015
# 3             Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015
# 4     Universal Pictures|Original Film|Media Rights ...     4/1/2015
# ...                                                 ...          ...
# 6642                                                NaN   12/12/2006
# 6643  Virtual Studios|Next Entertainment|Warner Bros...    5/12/2006
# 6644                  Universal Pictures|Depth of Field     3/4/2006
# 6645             New Line Cinema|FilmEngine|BenderSpink   10/10/2006
# 6646                                                NaN          NaN
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 0        5562.0           6.5        2015.0  1.379999e+08  1.392446e+09
# 1        6185.0           7.1        2015.0  1.379999e+08  3.481613e+08
# 2        2480.0           6.3        2015.0  1.012000e+08  2.716190e+08
# 3        5292.0           7.5        2015.0  1.839999e+08  1.902723e+09
# 4        2947.0           7.3        2015.0  1.747999e+08  1.385749e+09
# ...         ...           ...           ...           ...           ...
# 6642       31.0           5.5        2006.0  9.735022e+06  0.000000e+00
# 6643      313.0           5.3        2006.0  1.730671e+08  1.965120e+08
# 6644       43.0           4.6        2006.0  1.838838e+07  7.911357e+06
# 6645      146.0           4.4        2006.0  0.000000e+00  0.000000e+00
# 6646        NaN           NaN           NaN           NaN           NaN
#
# [6647 rows x 21 columns]>

# %%
# to check the number of rows and coloumn
df.tail()
# Out:
#          id    imdb_id  popularity     budget    revenue  \
# 6642   9973  tt0470982    0.826291    9000000          0
# 6643    503  tt0409182    0.826011  160000000  181674817
# 6644   9310  tt0465142    0.793804   17000000    7314027
# 6645  14620  tt0457297    0.793059          0          0
# 6646  14611  tt0803093    0.791780          0    7900000
#
#               original_title  \
# 6642             Air Buddies
# 6643                Poseidon
# 6644         American Dreamz
# 6645  The Butterfly Effect 2
# 6646     Ultimate Avengers 2
#
#                                                    cast  \
# 6642  Abigail Breslin|Trevor Wright|Slade Pearce|Mic...
# 6643  Kurt Russell|Richard Dreyfuss|Josh Lucas|Jacin...
# 6644  Hugh Grant|Dennis Quaid|Mandy Moore|Willem Daf...
# 6645  Eric Lively|Erica Durance|Dustin Milligan|Gina...
# 6646                                           Justin G
#
#                                                homepage           director  \
# 6642                                                NaN       Robert Vince
# 6643               http://www2.warnerbros.com/poseidon/  Wolfgang Petersen
# 6644                                                NaN         Paul Weitz
# 6645  http://www.newline.com/properties/butterflyeff...   John R. Leonetti
# 6646                                                NaN                NaN
#
#                                                 tagline  ...  \
# 6642                                                NaN  ...
# 6643                                             Mayday  ...
# 6644  Imagine a country where more people vote for a...  ...
# 6645  Can you change your past without destroying yo...  ...
# 6646                                                NaN  ...
#
#                                                overview runtime  \
# 6642  Hereâ€™s the delightful tale of teamwork and a...    80.0
# 6643  A packed cruise ship traveling the Atlantic is...    99.0
# 6644  The new season of "American Dreamz," the wildl...   107.0
# 6645  After his girlfriend, Julie and two best frien...    95.0
# 6646                                                NaN     NaN
#
#                                genres  \
# 6642    Comedy|Family|Science Fiction
# 6643  Adventure|Action|Drama|Thriller
# 6644              Comedy|Drama|Family
# 6645   Drama|Science Fiction|Thriller
# 6646                              NaN
#
#                                    production_companies release_date  \
# 6642                                                NaN   12/12/2006
# 6643  Virtual Studios|Next Entertainment|Warner Bros...    5/12/2006
# 6644                  Universal Pictures|Depth of Field     3/4/2006
# 6645             New Line Cinema|FilmEngine|BenderSpink   10/10/2006
# 6646                                                NaN          NaN
#
#      vote_count  vote_average  release_year    budget_adj   revenue_adj
# 6642       31.0           5.5        2006.0  9.735022e+06  0.000000e+00
# 6643      313.0           5.3        2006.0  1.730671e+08  1.965120e+08
# 6644       43.0           4.6        2006.0  1.838838e+07  7.911357e+06
# 6645      146.0           4.4        2006.0  0.000000e+00  0.000000e+00
# 6646        NaN           NaN           NaN           NaN           NaN
#
# [5 rows x 21 columns]

# %%
# statistic values for this data
df.describe()
# Out:
#                   id   popularity        budget       revenue      runtime  \
# count    6647.000000  6647.000000  6.647000e+03  6.647000e+03  6646.000000
# mean    97539.535129     0.716581  1.672192e+07  4.421989e+07   100.314926
# std    105219.812083     1.185849  3.481636e+07  1.333874e+08    34.155440
# min        11.000000     0.000065  0.000000e+00  0.000000e+00     0.000000
# 25%     14246.500000     0.208473  0.000000e+00  0.000000e+00    90.000000
# 50%     48186.000000     0.395538  0.000000e+00  0.000000e+00    97.000000
# 75%    163841.000000     0.786833  1.800000e+07  2.179281e+07   109.000000
# max    417859.000000    32.985763  4.250000e+08  2.781506e+09   900.000000
#
#         vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  6646.000000    6646.00000   6646.000000  6.646000e+03  6.646000e+03
# mean    263.337195       5.92105   2008.065302  1.798705e+07  4.787359e+07
# std     675.815481       0.97461      6.843512  3.645283e+07  1.443315e+08
# min      10.000000       2.00000   1977.000000  0.000000e+00  0.000000e+00
# 25%      17.000000       5.30000   2005.000000  0.000000e+00  0.000000e+00
# 50%      43.000000       6.00000   2010.000000  0.000000e+00  0.000000e+00
# 75%     181.000000       6.60000   2013.000000  1.961642e+07  2.437613e+07
# max    9767.000000       9.20000   2015.000000  4.250000e+08  2.827124e+09

# %%
# check the rows and columns of this dataset
df.shape
# Out:
# (6647, 21)

# %%
# check each columns number of unique values
df.nunique()
# Out:
# id                      6646
# imdb_id                 6638
# popularity              6627
# budget                   407
# revenue                 2813
# original_title          6575
# cast                    6553
# homepage                2405
# director                3933
# tagline                 4673
# keywords                5105
# overview                6633
# runtime                  225
# genres                  1475
# production_companies    4961
# release_date            3211
# vote_count              1115
# vote_average              69
# release_year              18
# budget_adj              1422
# revenue_adj             2840
# dtype: int64

# %%
df.isnull().sum()
# Out:
# id                         0
# imdb_id                    8
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      56
# homepage                4215
# director                  39
# tagline                 1946
# keywords                1157
# overview                   5
# runtime                    1
# genres                    18
# production_companies     708
# release_date               1
# vote_count                 1
# vote_average               1
# release_year               1
# budget_adj                 1
# revenue_adj                1
# dtype: int64

# %% [markdown]
# Data cleaning process by filling null values with mean and also drop duplicate data

# %%
# drop unuseful columns
df.drop(['id','imdb_id', 'homepage','overview'],axis=1,inplace=True)  # do not forget inplace

df.fillna(df.mean(), inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6647 entries, 0 to 6646
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            6647 non-null   float64
#  1   budget                6647 non-null   int64
#  2   revenue               6647 non-null   int64
#  3   original_title        6647 non-null   object
#  4   cast                  6591 non-null   object
#  5   director              6608 non-null   object
#  6   tagline               4701 non-null   object
#  7   keywords              5490 non-null   object
#  8   runtime               6647 non-null   float64
#  9   genres                6629 non-null   object
#  10  production_companies  5939 non-null   object
#  11  release_date          6646 non-null   object
#  12  vote_count            6647 non-null   float64
#  13  vote_average          6647 non-null   float64
#  14  release_year          6647 non-null   float64
#  15  budget_adj            6647 non-null   float64
#  16  revenue_adj           6647 non-null   float64
# dtypes: float64(7), int64(2), object(8)
# memory usage: 882.9+ KB
# <ipython-input-11-449d5a96f57e>:4: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace = True)

# %%
# calculate sum of null value for each coloumn
df.isnull().sum()
# Out:
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      56
# director                  39
# tagline                 1946
# keywords                1157
# runtime                    0
# genres                    18
# production_companies     708
# release_date               1
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# dtype: int64

# %%
# Drop null values for each coloumn containing null values
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3935 entries, 0 to 6645
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   popularity            3935 non-null   float64
#  1   budget                3935 non-null   int64
#  2   revenue               3935 non-null   int64
#  3   original_title        3935 non-null   object
#  4   cast                  3935 non-null   object
#  5   director              3935 non-null   object
#  6   tagline               3935 non-null   object
#  7   keywords              3935 non-null   object
#  8   runtime               3935 non-null   float64
#  9   genres                3935 non-null   object
#  10  production_companies  3935 non-null   object
#  11  release_date          3935 non-null   object
#  12  vote_count            3935 non-null   float64
#  13  vote_average          3935 non-null   float64
#  14  release_year          3935 non-null   float64
#  15  budget_adj            3935 non-null   float64
#  16  revenue_adj           3935 non-null   float64
# dtypes: float64(7), int64(2), object(8)
# memory usage: 553.4+ KB

# %%
# to replace all the zero value in coloumn with mean value.
df['popularity']=df['popularity'].replace(0,df['popularity'].mean())
df['revenue']=df['revenue'].replace(0,df['revenue'].mean())
df['runtime']=df['runtime'].replace(0,df['runtime'].mean())
df['budget_adj']=df['budget_adj'].replace(0,df['budget_adj'].mean())
df['revenue_adj']=df['revenue_adj'].replace(0,df['revenue_adj'].mean())

# %%
df.describe()
# Out:
#         popularity        budget       revenue      runtime   vote_count  \
# count  3935.000000  3.935000e+03  3.935000e+03  3935.000000  3935.000000
# mean      0.991178  2.604868e+07  9.993134e+07   103.817590   412.680559
# std       1.449540  4.168512e+07  1.574980e+08    25.803736   841.171115
# min       0.000620  0.000000e+00  3.000000e+00     4.000000    10.000000
# 25%       0.319939  0.000000e+00  3.055244e+07    91.000000    32.000000
# 50%       0.589183  8.000000e+06  7.195422e+07   100.000000   108.000000
# 75%       1.117221  3.500000e+07  7.195422e+07   112.000000   375.000000
# max      32.985763  4.250000e+08  2.781506e+09   705.000000  9767.000000
#
#        vote_average  release_year    budget_adj   revenue_adj
# count   3935.000000   3935.000000  3.935000e+03  3.935000e+03
# mean       5.959441   2007.244219  3.817511e+07  1.083176e+08
# std        0.906033      7.366578  3.868084e+07  1.705167e+08
# min        2.000000   1977.000000  9.693980e-01  1.000000e+01
# 25%        5.400000   2003.000000  1.947004e+07  3.409009e+07
# 50%        6.000000   2009.000000  2.803118e+07  7.799260e+07
# 75%        6.600000   2013.000000  3.798977e+07  7.799260e+07
# max        8.400000   2015.000000  4.250000e+08  2.827124e+09

# %%
# calculate sum of all duplicated value
df.duplicated().sum()
# Out:
# 1

# %%
# Drop duplicate value
df.drop_duplicates(inplace=True)

# %%
# calculate sum of all duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
# visulize each variables
df.hist(figsize=(18,18));

# %% [markdown]
# Exploration with Visuals and Conclusions
#
# The questions about this dataset:
#
# 1. Does higher budget mean higher popularity ?
#
# 2. Do the runtime affect the vote count and popularity?
#
# 3. Is Higher popularity means higher profits ?
#
# 4. What are the Features Associate with Top 10 Revenue Movies ?

# %% [markdown]
# EVALUATING QUESTION 1
#
# 1. Does higher budget mean higher popularity ?

# %%
# plot the relation between budget and popularity
x = df['budget']
y = df['popularity']

plt.scatter(x,y)
plt.title('Average Popularity by Different budget',fontsize=20)
plt.xlabel('budgete',fontsize=20)
plt.ylabel('popularity',fontsize=20)
# Out:
# Text(0, 0.5, 'popularity')

# %% [markdown]
# As per the above scatter plot its very difficult to observe strong relationship between popularity and budget. So we use other method to observe the relationship between them. In this method we divide data set in to two group on the basis of median.

# %%
# divide the budget into two groups : lesser_cost and more_cost.
med = df['budget'].median()
lesser_cost =  df.query('budget < {}'.format(med))
more_cost =  df.query('budget >= {}'.format(med))

# %%
# check lesser cost and more cost  mean values
mean_low_budget = lesser_cost['popularity'].mean()
mean_high_budget = more_cost['popularity'].mean()

# %%
# create a bar chart with the values we get above
locations = [1,2]
heights = [mean_low_budget , mean_high_budget]
labels=['low','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Mean Popularity by all Budget')
plt.xlabel('Budgets')
plt.ylabel('Mean Popularity')
# Out:
# Text(0, 0.5, 'Mean Popularity')

# %%
increase_percentage = (mean_high_budget - mean_low_budget) / mean_high_budget * 100
increase_percentage
# Out:
# 67.62801694007486

# %% [markdown]
# Answer for question 1
#
# From the above bar plot we conclude that higher budget movie gains higher popularity. Higher budget movie have Mean popularity more than twice than the Mean popularity of lower budget movie.

# %% [markdown]
# EVALUATING QUESTION 2
#
# 2. Do the runtime affect the vote count and popularity?

# %%
# There 3 groups with query().  <60 min: lowest   , 60 min <=  <= - 120 min: medium ,  >120 min: highest
lowest =  df.query('runtime < {}'.format(100))
med =  df.query('runtime < {}'.format(200))
highest = df.query('runtime > {}'.format(200))

# %%
# check mean popularity of different movie lengths
mean_of_lowest = lowest['popularity'].mean()
mean_of_med = med['popularity'].mean()
mean_of_highest = highest['popularity'].mean()

# %%
locations = [1,2,3]
heights = [mean_of_lowest, mean_of_med, mean_of_highest]
labels=['low','medium','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Average Popularity by Different Runtime')
plt.xlabel('Runtime')
plt.ylabel('Average Popularity')
# Out:
# Text(0, 0.5, 'Average Popularity')

# %%
# scatter plot between runtime and popularity
x = df['runtime']
y = df['popularity']

plt.scatter(x,y)

plt.title('Average Popularity by Different Runtime',fontsize=20)
plt.xlabel('runtime',fontsize=20)
plt.ylabel('popularity',fontsize=20)
# Out:
# Text(0, 0.5, 'popularity')

# %% [markdown]
# ANSWER FOR QUESTION 2
#
# From the above two plots, we can simply say that If the movies are within 200 minutes,it will be more popular. Once the movies run over 200 minutes, it's hard for them to gain high popularity
#
# EVALUATING QUESTION 3
#
# 3. Is Higher popularity means higher profits ?

# %%
# calculation for the mean of popularity
mean = df['popularity'].median()
lowest_popularity =  df.query('popularity < {}'.format(mean))
more_popularity =  df.query('popularity >= {}'.format(mean))

# %%
# create a new column called profit.
df['profit'] = df['revenue'] - df['budget']

# %%
# average net profit for low_popularity and high_popularity
mean_profit_of_low = lowest_popularity['profit'].mean()
mean_profit_of_high = more_popularity['profit'].mean()
df.head()
# Out:
#    popularity     budget       revenue                original_title  \
# 0   32.985763  150000000  1.513529e+09                Jurassic World
# 1   28.419936  150000000  3.784364e+08            Mad Max: Fury Road
# 2   13.112507  110000000  2.952382e+08                     Insurgent
# 3   11.173104  200000000  2.068178e+09  Star Wars: The Force Awakens
# 4    9.335014  190000000  1.506249e+09                     Furious 7
#
#                                                 cast          director  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...   Colin Trevorrow
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...     George Miller
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...  Robert Schwentke
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...       J.J. Abrams
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...         James Wan
#
#                          tagline  \
# 0              The park is open.
# 1             What a Lovely Day.
# 2     One Choice Can Destroy You
# 3  Every generation has a story.
# 4            Vengeance Hits Home
#
#                                             keywords  runtime  \
# 0  monster|dna|tyrannosaurus rex|velociraptor|island    124.0
# 1   future|chase|post-apocalyptic|dystopia|australia    120.0
# 2  based on novel|revolution|dystopia|sequel|dyst...    119.0
# 3              android|spaceship|jedi|space opera|3d    136.0
# 4                car race|speed|revenge|suspense|car    137.0
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date  vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...     6/9/2015      5562.0
# 1  Village Roadshow Pictures|Kennedy Miller Produ...    5/13/2015      6185.0
# 2  Summit Entertainment|Mandeville Films|Red Wago...    3/18/2015      2480.0
# 3          Lucasfilm|Truenorth Productions|Bad Robot   12/15/2015      5292.0
# 4  Universal Pictures|Original Film|Media Rights ...     4/1/2015      2947.0
#
#    vote_average  release_year   budget_adj   revenue_adj        profit
# 0           6.5        2015.0  137999939.3  1.392446e+09  1.363529e+09
# 1           7.1        2015.0  137999939.3  3.481613e+08  2.284364e+08
# 2           6.3        2015.0  101199955.5  2.716190e+08  1.852382e+08
# 3           7.5        2015.0  183999919.0  1.902723e+09  1.868178e+09
# 4           7.3        2015.0  174799923.1  1.385749e+09  1.316249e+09

# %%
# create a bar chart with the values we get above
locations = [1,2]
heights = [mean_profit_of_low, mean_profit_of_high]
labels=['low','high']
plt.bar(locations, heights, tick_label = labels)
plt.title('Average profit by Different Popularity')
plt.xlabel('Popularity')
plt.ylabel('Average Profit')
# Out:
# Text(0, 0.5, 'Average Profit')

# %% [markdown]
# ANSWER FOR QUESTION 3
#
# From the above graph we observe that higher popularity leads to more Average profit.
#
# EVALUATING QUESTION 4
#
# 4. What are the Features Associate with Top 10 Revenue Movies ?

# %%
top10_revenue = df.nlargest(10,'revenue')
top10_revenue.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'popularity'}>,
#         <Axes: title={'center': 'budget'}>,
#         <Axes: title={'center': 'revenue'}>],
#        [<Axes: title={'center': 'runtime'}>,
#         <Axes: title={'center': 'vote_count'}>,
#         <Axes: title={'center': 'vote_average'}>],
#        [<Axes: title={'center': 'release_year'}>,
#         <Axes: title={'center': 'budget_adj'}>,
#         <Axes: title={'center': 'revenue_adj'}>],
#        [<Axes: title={'center': 'profit'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ANSWER FOR QUESTION 4
#
# From the above plot we conclude that Runtime ranges from 100 mins to 200 mins. The released year are between 1995 to 2015 leads to top 10 revenue movies.

# %% [markdown]
# CONCLUSION
#  1. Higher budget movie gains higher popularity. Higher budget movie have Mean popularity more than twice than the Mean popularity of lower budget movie.
#
#  2. If the movies are within 200 minutes,it will be more popular. Once the movies run over 200 minutes, it's hard for them to gain high popularity.
#
#  3. Higher popularity leads to more Average profit.
#
#  4. Runtime ranges from 100 mins to 200 mins. The released year are between 1995 to 2015 leads to top 10 revenue movies.

# %% [markdown]
# LIMITATIONS
# 1. There are plenty of missing data and many zeros which effect the data analysis process.
#
# 2. Its very difficult to know how the measurement should be done for coloumn like vote_counts and popularity.
#
# 3. For movies outside the country currency is not indicated. So its also effect the data analysis process.
#
# REFERENCE
# 1. I mainly watch instructor video to know the data analysis process after watching video i follow the same steps.
#
# 2. I have also paid account of Data Camp. So i also refer some steps from there.
